# %%
import pandas as pd

from copairs.sampler import Sampler

# %%
df = pd.read_parquet("output/profiles.parquet")
df.shape
# Out:
# (736, 17)

# %%
meta = df.filter(regex="^Metadata_")
meta.head()
# Out:
#   Metadata_JCP2022 Metadata_broad_sample         Metadata_Name  \
# 0   JCP2022_900004    ccsbBroad304_00003  ORF003876.1_TRC304.1
# 1   JCP2022_900007    ccsbBroad304_00009  ORF009407.1_TRC304.1
# 2   JCP2022_900049    ccsbBroad304_00055  ORF014476.1_TRC304.1
# 3   JCP2022_900054    ccsbBroad304_00060  ORF013533.1_TRC304.1
# 4   JCP2022_900068    ccsbBroad304_00075  ORF015244.1_TRC304.1
#
#   Metadata_Vector Metadata_Transcript Metadata_Symbol Metadata_NCBI_Gene_ID  \
# 0         pLX_304         NM_000663.4            ABAT                    18
# 1         pLX_304         NM_001096.3            ACLY                    47
# 2         pLX_304         NM_001628.4          AKR1B1                   231
# 3         pLX_304         NM_001633.4            AMBP                   259
# 4         pLX_304         NM_001638.4            APOF                   319
#
#   Metadata_Taxon_ID                Metadata_Gene_Description  \
# 0              9606         4-aminobutyrate aminotransferase
# 1              9606                        ATP citrate lyase
# 2              9606    aldo-keto reductase family 1 member B
# 3              9606  alpha-1-microglobulin/bikunin precursor
# 4              9606                         apolipoprotein F
#
#    Metadata_Prot_Match  Metadata_Insert_Length Metadata_pert_type  \
# 0                100.0                  1500.0                trt
# 1                100.0                  3303.0                trt
# 2                100.0                   948.0                trt
# 3                100.0                  1056.0                trt
# 4                100.0                   978.0                trt
#
#   Metadata_Source Metadata_Plate Metadata_Well
# 0        source_4     BR00125634           M20
# 1        source_4     BR00125634           F03
# 2        source_4     BR00126060           K18
# 3        source_4     BR00125634           N24
# 4        source_4     BR00125634           B17

# %%
meta
# Out:
#     Metadata_JCP2022 Metadata_broad_sample         Metadata_Name  \
# 0     JCP2022_900004    ccsbBroad304_00003  ORF003876.1_TRC304.1
# 1     JCP2022_900007    ccsbBroad304_00009  ORF009407.1_TRC304.1
# 2     JCP2022_900049    ccsbBroad304_00055  ORF014476.1_TRC304.1
# 3     JCP2022_900054    ccsbBroad304_00060  ORF013533.1_TRC304.1
# 4     JCP2022_900068    ccsbBroad304_00075  ORF015244.1_TRC304.1
# ..               ...                   ...                   ...
# 731   JCP2022_915132    ccsbBroad304_99997  ORFC00005.1_TRC304.1
# 732   JCP2022_915132    ccsbBroad304_99997  ORFC00005.1_TRC304.1
# 733   JCP2022_915132    ccsbBroad304_99997  ORFC00005.1_TRC304.1
# 734   JCP2022_915132    ccsbBroad304_99997  ORFC00005.1_TRC304.1
# 735   JCP2022_915132    ccsbBroad304_99997  ORFC00005.1_TRC304.1
#
#     Metadata_Vector Metadata_Transcript Metadata_Symbol Metadata_NCBI_Gene_ID  \
# 0           pLX_304         NM_000663.4            ABAT                    18
# 1           pLX_304         NM_001096.3            ACLY                    47
# 2           pLX_304         NM_001628.4          AKR1B1                   231
# 3           pLX_304         NM_001633.4            AMBP                   259
# 4           pLX_304         NM_001638.4            APOF                   319
# ..              ...                 ...             ...                   ...
# 731         pLX_304              eGFP.1            eGFP                  eGFP
# 732         pLX_304              eGFP.1            eGFP                  eGFP
# 733         pLX_304              eGFP.1            eGFP                  eGFP
# 734         pLX_304              eGFP.1            eGFP                  eGFP
# 735         pLX_304              eGFP.1            eGFP                  eGFP
#
#     Metadata_Taxon_ID                Metadata_Gene_Description  \
# 0                9606         4-aminobutyrate aminotransferase
# 1                9606                        ATP citrate lyase
# 2                9606    aldo-keto reductase family 1 member B
# 3                9606  alpha-1-microglobulin/bikunin precursor
# 4                9606                         apolipoprotein F
# ..                ...                                      ...
# 731           CONTROL                            Hahn Lab eGFP
# 732           CONTROL                            Hahn Lab eGFP
# 733           CONTROL                            Hahn Lab eGFP
# 734           CONTROL                            Hahn Lab eGFP
# 735           CONTROL                            Hahn Lab eGFP
#
#      Metadata_Prot_Match  Metadata_Insert_Length Metadata_pert_type  \
# 0                  100.0                  1500.0                trt
# 1                  100.0                  3303.0                trt
# 2                  100.0                   948.0                trt
# 3                  100.0                  1056.0                trt
# 4                  100.0                   978.0                trt
# ..                   ...                     ...                ...
# 731                100.0                   717.0             poscon
# 732                100.0                   717.0             poscon
# 733                100.0                   717.0             poscon
# 734                100.0                   717.0             poscon
# 735                100.0                   717.0             poscon
#
#     Metadata_Source Metadata_Plate Metadata_Well
# 0          source_4     BR00125634           M20
# 1          source_4     BR00125634           F03
# 2          source_4     BR00126060           K18
# 3          source_4     BR00125634           N24
# 4          source_4     BR00125634           B17
# ..              ...            ...           ...
# 731        source_4     BR00126060           O20
# 732        source_4     BR00126060           P17
# 733        source_4     BR00126060           P18
# 734        source_4     BR00126060           P19
# 735        source_4     BR00126060           P20
#
# [736 rows x 15 columns]

# %%
pert_sampler = Sampler(meta.query('Metadata_pert_type != "poscon"'), meta.columns, seed=0)
pert_pairs = pert_sampler.get_all_pairs(groupby=["Metadata_pert_type"], diffby=["Metadata_replicate"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 2
#       1 pert_sampler = Sampler(meta.query('Metadata_pert_type != "poscon"'), meta.columns, seed=0)
# ----> 2 pert_pairs = pert_sampler.get_all_pairs(groupby=["Metadata_pert_type"], diffby=["Metadata_replicate"])
#
# File ~/Projects/copairs/src/copairs/sampler.py:85, in Sampler.get_all_pairs(self, groupby, diffby)
#      83 if len(groupby) == 1:
#      84     key = next(iter(groupby))
# ---> 85     return self._get_all_pairs_single(key, diffby)
#      87 # Multiple groupby. Ordering by minimum number of posible pairs
#      88 groupby_ix = [self.col_to_ix[col] for col in groupby]
#
# File ~/Projects/copairs/src/copairs/sampler.py:108, in Sampler._get_all_pairs_single(self, groupby, diffby)
#     106 if isinstance(groupby, str):
#     107     groupby = self.col_to_ix[groupby]
# --> 108 diffby_ix = [self.col_to_ix[col] for col in diffby]
#     109 index = self.reverse[groupby]
#     110 pairs = defaultdict(list)
#
# File ~/Projects/copairs/src/copairs/sampler.py:108, in <listcomp>(.0)
#     106 if isinstance(groupby, str):
#     107     groupby = self.col_to_ix[groupby]
# --> 108 diffby_ix = [self.col_to_ix[col] for col in diffby]
#     109 index = self.reverse[groupby]
#     110 pairs = defaultdict(list)
#
# KeyError: 'Metadata_replicate'

# %%
meta.query('Metadata_pert_type == "trt"').groupby("Metadata_JCP2022")["Metadata_pert_type"].count().unique()
# Out:
# array([4, 1])

# %% [markdown]
# ### TODO: download bigger sample of full data to have replicates of the same perturbation
